# %%
import numpy as np
import newton_funcn

# %%
def test_fnct(x):
    return x**2
    
newton_funct.neuton_raphson(1, 1, 0.0000001)

newton_funct.neuton_raphson(1, test_fnct, 0.0000001)

# %%
# Out:
# 0

# %%
# Out:
# Help on function dd in module __main__:
#
# dd(x, f, eps=1e-08)
#     Second Derivative funtion
